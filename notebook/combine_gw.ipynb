# %%
import pandas as pd
import numpy as np
import os

# %%
folder_path = "D:\FPL-Lineup-Prediction\output\csv"

files = [f for f in os.listdir(folder_path)
         if os.path.isfile(os.path.join(folder_path,f))]

files
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\ramgo\AppData\Local\Temp\ipykernel_45448\290701613.py:1: SyntaxWarning: invalid escape sequence '\F'
#   folder_path = "D:\FPL-Lineup-Prediction\output\csv"
# ['gw_10_players.csv',
#  'gw_11_players.csv',
#  'gw_12_players.csv',
#  'gw_1_players.csv',
#  'gw_2_players.csv',
#  'gw_3_players.csv',
#  'gw_4_players.csv',
#  'gw_5_players.csv',
#  'gw_6_players.csv',
#  'gw_7_players.csv',
#  'gw_8_players.csv',
#  'gw_9_players.csv']

# %%
files[0]
# Out:
# 'gw_10_players.csv'
